# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

sns.set_theme(style="whitegrid")

# %%
DATA_PATH = r"C:\xampp\htdocs\Smart Property Valuer FYP\dataset_with_url.csv"
TARGET_COL = "Price"
TEST_SIZE = 0.20
RANDOM_STATE = 42

MODEL_NUMERIC_COLUMNS = [
    "Built_Up_SF", "Bathroom", "Furnishing", "Bedroom",
    "Tenure", "Car_Park", "Property_Type", "Land_Size", "Unit_Type"
]

RF_AFTER_PARAMS = {
    "n_estimators": 400,
    "max_depth": 20,
    "min_samples_split": 4,
    "min_samples_leaf": 2,
    "random_state": RANDOM_STATE,
    "n_jobs": -1
}

XGB_AFTER_PARAMS = {
    "objective": "reg:squarederror",
    "n_estimators": 200,
    "learning_rate": 0.05,
    "max_depth": 7,
    "subsample": 0.9,
    "colsample_bytree": 0.8,
    "random_state": RANDOM_STATE,
    "n_jobs": -1
}

# %%
df = pd.read_csv(DATA_PATH).copy()
df = df.drop(columns=[c for c in df.columns if "Unnamed" in c], errors="ignore")

if TARGET_COL not in df.columns:
    raise ValueError(f"Target column '{TARGET_COL}' not found.")

if "negeri" in df.columns:
    state_col = "negeri"
elif "Negeri" in df.columns:
    state_col = "Negeri"
else:
    raise ValueError("State column not found. Need 'negeri' or 'Negeri'.")

work = df.copy()
work[TARGET_COL] = pd.to_numeric(work[TARGET_COL], errors="coerce")
work["state_text"] = work[state_col].astype(str).str.strip()
work = work.dropna(subset=[TARGET_COL]).copy()

for col in MODEL_NUMERIC_COLUMNS:
    if col not in work.columns:
        work[col] = 0.0
    work[col] = pd.to_numeric(work[col], errors="coerce").fillna(0.0)

print("Dataset shape after clean:", work.shape)
print("Using state column:", state_col)
work.head(3)
# Out:
# Dataset shape after clean: (5981, 24)
# Using state column: Negeri
#   Property_ID                                                URL   Price  \
# 0         P01  https://www.durianproperty.com.my/classified/3...  600000
# 1         P02  https://www.durianproperty.com.my/classified/3...  420000
# 2         P03  https://www.durianproperty.com.my/classified/3...  620000
#
#    Built_Up_SF  Bathroom  Furnishing  Bedroom  Tenure  Car_Park  \
# 0         1400         4           1        5       1         2
# 1         1365         3           1        4       2         2
# 2         1800         3           1        4       1         2
#
#                 Agent_Name  ...  \
# 0        Shahrizal Shahrir  ...
# 1  Md Razif Bin Mohd Salim  ...
# 2       Rafedah Abdul Aziz  ...
#
#                                     Property_Address Occupancy Unit_Type  \
# 0  Taman Sri Kenari, Kajang - Terrace House For Sale       0.0         0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, shuffle=True
)

model = XGBRegressor(**XGBOOST_AFTER_TUNED_PARAMS)
model.fit(X_train, y_train)

print("Train/Test:", X_train.shape, X_test.shape)
print("Model trained successfully.")
# Out:
# Train/Test: (4784, 23) (1197, 23)
# Model trained successfully.

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

safe_y = np.where(np.asarray(y_test) <= 0, 1.0, y_test)
mape = np.mean(np.abs((np.asarray(y_test) - np.asarray(y_pred)) / safe_y)) * 100.0
estimated_accuracy = max(0.0, min(100.0, 100.0 - mape))

metrics_df = pd.DataFrame([{
    "Model": "XGBoost",
    "Condition": "After Tuning",
    "MAE": mae,
    "RMSE": rmse,
    "R² Score": r2,
    "MAPE (%)": mape,
    "Estimated Accuracy (%)": estimated_accuracy
}])

display(metrics_df.round(4))
# Out:
#      Model     Condition         MAE         RMSE  R² Score  MAPE (%)  \
# 0  XGBoost  After Tuning  81452.2591  119424.1978    0.7194   20.1859
#
#    Estimated Accuracy (%)
# 0                 79.8141

# %%
# Bar chart for key metrics
plot_df = pd.DataFrame({
    "Metric": ["MAE", "RMSE", "R² Score", "MAPE (%)", "Estimated Accuracy (%)"],
    "Value": [mae, rmse, r2, mape, estimated_accuracy]
})

plt.figure(figsize=(8,5))
sns.barplot(data=plot_df, x="Metric", y="Value", palette="viridis")
plt.title("XGBoost After Tuning - Evaluation Metrics")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# Actual vs Predicted
plt.figure(figsize=(7,6))
plt.scatter(y_test, y_pred, alpha=0.6, edgecolors="k", linewidth=0.2)
vmin = min(y_test.min(), y_pred.min())
vmax = max(y_test.max(), y_pred.max())
plt.plot([vmin, vmax], [vmin, vmax], "r--", linewidth=2, label="Ideal")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted - XGBoost (After Tuning)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
joblib.dump(model, MODEL_PATH)
joblib.dump(feature_columns, FEATURE_COLUMNS_PATH)

print("Saved model to:", MODEL_PATH)
print("Saved feature columns to:", FEATURE_COLUMNS_PATH)

# Verify saved model type and params
loaded_model = joblib.load(MODEL_PATH)
print("\nLoaded model type:", type(loaded_model).__name__)
print("Loaded key params:")
for k in ["n_estimators", "max_depth", "learning_rate", "subsample", "colsample_bytree", "objective", "random_state"]:
    print(f"  {k}: {loaded_model.get_params().get(k)}")
# Out:
# Saved model to: C:\xampp\htdocs\Smart Property Valuer FYP\models\best_model.pkl
# Saved feature columns to: C:\xampp\htdocs\Smart Property Valuer FYP\models\model_columns.pkl
#
# Loaded model type: XGBRegressor
# Loaded key params:
#   n_estimators: 200
#   max_depth: 7
#   learning_rate: 0.05
#   subsample: 0.9
#   colsample_bytree: 0.8
#   objective: reg:squarederror
#   random_state: 42
